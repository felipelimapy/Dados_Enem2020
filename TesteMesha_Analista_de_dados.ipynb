# %%
import pandas as pd

# %%
df= pd.read_csv("MICRODADOS_ENEM_2020.csv", encoding='ISO-8859-1', sep=";")

# %%
dados_selecionados=df[['TP_COR_RACA','TP_SEXO','TP_ESCOLA', 'NU_NOTA_MT', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_CN', 'NU_NOTA_REDACAO']]

# %%
dados_selecionados['NOTAS_TOTAIS']= 0
#criação de uma nova coluna pra armazenarmos a nota total de cada candidato
# Out:
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_selecionados['NOTAS_TOTAIS']= (dados_selecionados['NU_NOTA_CN'] + dados_selecionados["NU_NOTA_LC"]+
                                     dados_selecionados['NU_NOTA_CN']+ dados_selecionados['NU_NOTA_MT']+
                                    dados_selecionados['NU_NOTA_REDACAO'])/5
#cálculo pra sabermos a nota total de cada candidato
# Out:
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dados_selecionados
# Out:
#          TP_COR_RACA TP_SEXO  TP_ESCOLA  NU_NOTA_MT  NU_NOTA_CH  NU_NOTA_LC  \
# 0                  2       F          1         NaN         NaN         NaN
# 1                  3       M          1       711.3       661.7       595.3
# 2                  3       F          2         NaN         NaN         NaN
# 3                  3       M          2       759.4       675.0       624.2
# 4                  3       F          1         NaN         NaN         NaN
# 5                  3       F          1       526.7       604.7       505.4
# 6                  3       M          1         NaN         NaN         NaN
# 7                  1       M          1       753.2       604.8       562.1
# 8                  3       F          1       448.5       383.5       486.2
# 9                  2       M          2         NaN         NaN         NaN
# 10                 1       M          1         NaN         NaN         NaN
# ...

# %%
dados_selecionados['TP_ESCOLA']=dados_selecionados['TP_ESCOLA'].astype(object)
dados_selecionados['TP_COR_RACA']=dados_selecionados['TP_COR_RACA'].astype(object)

#função DAX = tranformando números em textos
# Out:
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dados_selecionados['TP_ESCOLA']=dados_selecionados['TP_ESCOLA'].replace([1,2,3,4],['nao respondeu', 'publica', 'privada', 'exterior'])
dados_selecionados['TP_COR_RACA']=dados_selecionados['TP_COR_RACA'].replace([0,1,2,3,4,5], ['nao declarou', 'branca', 'preta', 'parda', 'amarela', 'indigena'])

#atribuindo textos nos valores
# Out:
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/felipesilva/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dados_selecionados=dados_selecionados.dropna()
#eliminando linhas sem valores

# %%
dados_selecionados
# Out:
#           TP_COR_RACA TP_SEXO      TP_ESCOLA  NU_NOTA_MT  NU_NOTA_CH  \
# 1               parda       M  nao respondeu       711.3       661.7
# 3               parda       M        publica       759.4       675.0
# 5               parda       F  nao respondeu       526.7       604.7
# 7              branca       M  nao respondeu       753.2       604.8
# 8               parda       F  nao respondeu       448.5       383.5
# 11             branca       M  nao respondeu       546.5       631.4
# 18              parda       F  nao respondeu       420.3       488.1
# 19              preta       M  nao respondeu       405.6       503.3
# 22              parda       F  nao respondeu       746.4       667.2
# 24              preta       F  nao respondeu       542.8       588.9
# 26              preta       F  nao respondeu       561.6       436.2
# 27              parda       F  nao respondeu       596.5       591.2
# 29             branca       F  nao respondeu       664.9       598.0
# ...

# %% [markdown]
# 1-Qual a escola com a maior média de notas?

# %%
ordenados=dados_selecionados.groupby(by="TP_ESCOLA").mean()
ordenados.sort_values("NOTAS_TOTAIS",ascending=False)
# Out:
#                NU_NOTA_MT  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  \
# TP_ESCOLA
# privada        610.698214  576.302829  572.515367  548.409506
# nao respondeu  520.186538  515.180686  526.179352  491.440056
# publica        499.649508  496.305134  513.927712  473.558821
#
#                NU_NOTA_REDACAO  NOTAS_TOTAIS
# TP_ESCOLA
# privada             721.360875    600.278694
# nao respondeu       576.704632    521.190127
# publica             558.862515    503.911476

# %% [markdown]
# 2-Qual o aluno com a maior média de notas e o valor dessa média?

# %%
dados_selecionados.max()
# Out:
# TP_COR_RACA          preta
# TP_SEXO                  M
# TP_ESCOLA          publica
# NU_NOTA_MT             975
# NU_NOTA_CH           862.6
# NU_NOTA_LC           801.1
# NU_NOTA_CN           854.8
# NU_NOTA_REDACAO       1000
# NOTAS_TOTAIS        860.94
# dtype: object

# %% [markdown]
# 3-Qual a média geral?

# %%
dados_selecionados['NOTAS_TOTAIS'].mean()
# Out:
# 521.8302108603132

# %% [markdown]
# 4-Qual o % de Ausentes?

# %%
total=df['NU_INSCRICAO'].shape
total2=dados_selecionados.shape

# %%
total
# Out:
# (5783109,)

# %%
total2
# Out:
# (2588681,)

# %%
5783109-2588681
# Out:
# 3194428

# %%
((3194428*100)/5783109)
# Out:
# 55.237208913060435

# %% [markdown]
# 5-Qual o número total de Inscritos?

# %%
df['NU_INSCRICAO'].shape
# Out:
# (5783109,)

# %% [markdown]
# 6-Qual a média por disciplina?

# %%
dados_selecionados[['NU_NOTA_MT', 'NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_CN','NU_NOTA_REDACAO']].mean()
# Out:
# NU_NOTA_MT         520.727299
# NU_NOTA_CH         514.286982
# NU_NOTA_LC         526.019202
# NU_NOTA_CN         490.534635
# NU_NOTA_REDACAO    581.335282
# dtype: float64

# %% [markdown]
# 7-Qual a média por Sexo?

# %%
dados_selecionados.groupby(by='TP_SEXO').mean()
# Out:
#          NU_NOTA_MT  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  NU_NOTA_REDACAO  \
# TP_SEXO
# F        500.825648  505.583836  523.715002  480.325099       595.774972
# M        551.106263  527.571939  529.536460  506.119026       559.293755
#
#          NOTAS_TOTAIS
# TP_SEXO
# F          516.193164
# M          530.434906

# %% [markdown]
# 8- Qual a média por etnia?

# %%
ordenados2=dados_selecionados.groupby(by='TP_COR_RACA').mean()
ordenados2.sort_values("NOTAS_TOTAIS",ascending=False)
# Out:
#               NU_NOTA_MT  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_CN  NU_NOTA_REDACAO  \
# TP_COR_RACA
# branca        557.731909  541.211004  547.460972  513.274558       622.955168
# nao declarou  530.852546  525.745548  531.742550  499.981854       581.929200
# amarela       522.646086  509.029203  522.099920  491.120295       579.796689
# parda         498.909365  497.546313  512.233677  476.700432       557.897721
# preta         486.463739  493.328081  511.785220  470.741714       542.022757
# indigena      463.130770  468.550519  483.522721  453.439678       495.574651
#
#               NOTAS_TOTAIS
# TP_COR_RACA
# branca          550.939433
# nao declarou    528.897601
# amarela         521.356657
# parda           504.488326
# preta           496.351029
# indigena        469.821499
